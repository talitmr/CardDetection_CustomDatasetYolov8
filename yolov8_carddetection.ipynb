# %% [markdown]
# **Card Detection using YOLOv8**

# %% [markdown]
# In this notebook training YOLOv8 model with custom dataset was experimented.

# %% [markdown]
# First install and import necesseray libraries.

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.5/605.5 kB 9.7 MB/s eta 0:00:00
# ...

# %%
# !pip install clearml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# ...

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# Get the current directory
current_directory = os.getcwd()
print("Current Directory:", current_directory)
# Out:
# Current Directory: /content

# %%
os.chdir('/content/drive/My Drive/cnn_yolo_stajyer/')
os.getcwd()
# Out:
# '/content/drive/My Drive/cnn_yolo_stajyer'

# %% [markdown]
# YOLOv8 has different pretrained models:
#
# *   YOLOv8n (Nano model)
# *   YOLOv8s (Small model)
# *   YOLOv8m (Medium model)
#
# all models can be selected to train a new model with a custom dataset

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml name="yolov8s_custom"
# Out:
# Ultralytics YOLOv8.0.146 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model="runs/detect/yolov8n_custom/weights/best.pt" source="yolo_test_ex.mp4"
# Out:
# Ultralytics YOLOv8.0.142 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# video 1/1 (1/530) /content/drive/MyDrive/cnn_yolo_stajyer/yolo_test_ex.mp4: 384x640 1 card, 72.0ms
# video 1/1 (2/530) /content/drive/MyDrive/cnn_yolo_stajyer/yolo_test_ex.mp4: 384x640 1 card, 11.1ms
# video 1/1 (3/530) /content/drive/MyDrive/cnn_yolo_stajyer/yolo_test_ex.mp4: 384x640 1 card, 11.1ms
# video 1/1 (4/530) /content/drive/MyDrive/cnn_yolo_stajyer/yolo_test_ex.mp4: 384x640 1 card, 11.1ms
# video 1/1 (5/530) /content/drive/MyDrive/cnn_yolo_stajyer/yolo_test_ex.mp4: 384x640 1 card, 15.1ms
# video 1/1 (6/530) /content/drive/MyDrive/cnn_yolo_stajyer/yolo_test_ex.mp4: 384x640 1 card, 11.1ms
# video 1/1 (7/530) /content/drive/MyDrive/cnn_yolo_stajyer/yolo_test_ex.mp4: 384x640 1 card, 11.2ms
# video 1/1 (8/530) /content/drive/MyDrive/cnn_yolo_stajyer/yolo_test_ex.mp4: 384x640 1 card, 11.1ms
# ...

# %%
# !yolo task=detect mode=predict model="runs/detect/yolov8n_custom/weights/best.pt" source="federal-limits-divers-license-image.jpg"
# Out:
# Ultralytics YOLOv8.0.146 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# image 1/1 /content/drive/MyDrive/cnn_yolo_stajyer/federal-limits-divers-license-image.jpg: 640x512 1 card, 63.8ms
# Speed: 3.1ms preprocess, 63.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs/detect/predict4
